# %%
import pandas as pd 
import numpy as np

# %%
ADP_df = pd.DataFrame(pd.read_csv('FantasyPros_2025_Overall_MLB_ADP_Rankings.csv'))
ADP_df = ADP_df[['Rank','Player','Team','Positions', 'Yahoo']].dropna()


ADP_df
# Out:
#       Rank                  Player Team    Positions  Yahoo
# 1      2.0  Shohei Ohtani (Batter)  LAD           DH    1.0
# 2      3.0          Bobby Witt Jr.   KC           SS    2.0
# 3      4.0             Aaron Judge  NYY  LF,CF,RF,DH    3.0
# 4      5.0         Elly De La Cruz  CIN           SS    4.0
# 5      6.0            Jose Ramirez  CLE        3B,DH    5.0
# ..     ...                     ...  ...          ...    ...
# 498  499.0            Landen Roupp   SF        SP,RP  399.0
# 499  500.0           Robert Garcia  TEX           RP  306.0
# 510  511.0            Tyler Kinley  COL           RP  372.0
# 513  514.0            Tommy Kahnle  DET           RP  291.0
# 518  519.0             Marc Church  TEX           RP  407.0
#
# [405 rows x 5 columns]
