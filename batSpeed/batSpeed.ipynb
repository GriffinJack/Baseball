# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import shapiro
from scipy import stats

# %% [markdown]
# ### The importance of bat speed.
#
# Questions to anwser:
# - Does and increase in bat speed result in more swings and misses?
# - If so, is the increase in swinging strikes worth the power increase?
# - What other stats correlate with bat speed?

# %%
pd.set_option('display.max_columns', None)  # Show all columns

# %%
#read in data
data = pd.read_csv('batSpeed.csv')
data = pd.DataFrame(data)

# drop unnecessary columns 
data = data.drop([
        "pos3_int_start_distance",
        "pos4_int_start_distance",
        "pos5_int_start_distance",
        "pos6_int_start_distance",
        "pos7_int_start_distance",
        "pos8_int_start_distance",
        "pos9_int_start_distance",
        "pitches",
        "total_pitches",
        'bb'], axis = 1)

# %%
# Distribution of bat_speed 
data['bat_speed'].hist(bins=30)
plt.title('Bat Speed Distribution')
plt.xlabel("Bat Speed")
plt.ylabel('Frequency')
plt.show()

# %%
#Run Shapiro-Wilk test to check for normallity 
stat, p = shapiro(data['bat_speed'])
print(f'Shapiro-Wilk Test p-value: {p}')
# Out:
# Shapiro-Wilk Test p-value: 0.4113048315048218

# %% [markdown]
# Since p = 0.411 > 0.05
#
# - fail to reject null hypothesis
# - Bat Speed is likely normally distributed

# %%
#Distribution of swing and miss percent

data['swing_miss_percent'].hist(bins=30)
plt.title('Swing and Miss percent Distribution')
plt.xlabel("Swing and Miss %")
plt.ylabel('Frequency')
plt.show()

# %%
#Run Shapiro-Wilk test to check for normallity 
stat, p = shapiro(data['swing_miss_percent'])
print(f'Shapiro-Wilk Test p-value: {p}')
# Out:
# Shapiro-Wilk Test p-value: 0.8801288604736328

# %% [markdown]
# Since p = 0.88 > 0.05
#
# - fail to reject null hypothesis
# - Swing and Miss Percent is likely normally distributed

# %%
#Distribution of barrels per plate apperance

data['barrels_per_pa_percent'].hist(bins=30)
plt.title('barrels_per_pa_percent Distribution')
plt.xlabel("barrels_per_pa_percent")
plt.ylabel('Frequency')
plt.show()

# %%
#Run Shapiro-Wilk test to check for normallity 
stat, p = shapiro(data['barrels_per_pa_percent'])
print(f'Shapiro-Wilk Test p-value: {p}')
# Out:
# Shapiro-Wilk Test p-value: 6.060781032601881e-08

# %% [markdown]
# Since p = 0.00000006 < 0.05
#
# - Reject null hypothesis
# - barrels_per_pa_percent is likely not normally distributed

# %% [markdown]
# Now I will create a data frame identifying what stats are normially distributed.
#
# This should make it easier to find correlations later as the distribution of the stat will dictate what correlation formula we will use.

# %%
column_n = np.array([])
p_value = np.array([])

for column in data.columns: 
    if column == 'player_name':
        continue
    stat, p = shapiro(data.select_dtypes(include=[np.number])[column])
    column_n = np.append(column_n, column)
    p_value = np.append(p_value, p)

p_values = pd.DataFrame({"Stat" : column_n, 'p_value': p_value})
p_values["Normality"] = p_values['p_value'] > 0.05
# Out:
# C:\Users\Griffin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\stats\_morestats.py:1797: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "

# %%
p_values
# Out:
#                          Stat       p_value  Normality
# 0                   player_id  2.517046e-20      False
# 1               pitch_percent  1.723264e-01       True
# 2                          ba  2.569350e-01       True
# 3                         iso  2.383090e-04      False
# 4                       babip  5.361084e-01       True
# 5                         slg  5.176713e-05      False
# 6                        woba  4.850136e-04      False
# 7                       xwoba  3.493438e-09      False
# 8                         xba  2.433493e-02      False
# 9                        hits  4.477407e-08      False
# 10                        abs  5.211918e-09      False
# 11               launch_speed  1.083331e-01       True
# 12               launch_angle  8.165199e-01       True
# 13                  spin_rate  6.385784e-01       True
# 14                   velocity  1.791202e-01       True
# 15            effective_speed  5.879905e-01       True
# 16                     whiffs  1.937390e-10      False
# 17                     swings  2.648598e-08      False
# 18                      takes  1.000000e+00       True
# 19                eff_min_vel  3.418687e-12      False
# 20          release_extension  2.204433e-02      False
# 21            pitcher_run_exp  3.534037e-10      False
# 22                    run_exp  3.533814e-10      False
# 23                  bat_speed  4.113048e-01       True
# 24               swing_length  1.185425e-03      False
# 25                         pa  4.607165e-09      False
# 26                        bip  2.924196e-08      False
# 27                    singles  3.592110e-06      False
# 28                    doubles  2.767033e-08      False
# 29                    triples  8.665102e-25      False
# 30                        hrs  1.770432e-15      False
# 31                         so  9.286199e-10      False
# 32                  k_percent  5.982301e-02       True
# 33                 bb_percent  1.000000e+00       True
# 34   api_break_z_with_gravity  2.956689e-01       True
# 35        api_break_z_induced  2.308731e-02      False
# 36            api_break_x_arm  2.547619e-01       True
# 37      api_break_x_batter_in  4.397320e-06      False
# 38                hyper_speed  6.767042e-05      False
# 39                     bbdist  4.931602e-02      False
# 40            hardhit_percent  4.575801e-02      False
# 41    barrels_per_bbe_percent  8.512107e-08      False
# 42     barrels_per_pa_percent  6.060781e-08      False
# 43              release_pos_z  6.970774e-02       True
# 44              release_pos_x  1.660637e-08      False
# 45                    plate_x  7.132670e-02       True
# 46                    plate_z  1.778172e-01       True
# 47                        obp  4.210239e-01       True
# 48              barrels_total  2.533447e-17      False
# 49   batter_run_value_per_100  4.815865e-02      False
# 50                       xobp  1.829412e-02      False
# 51                       xslg  3.848326e-10      False
# 52  pitcher_run_value_per_100  4.817481e-02      False
# 53                    xbadiff  1.989708e-01       True
# 54                   xobpdiff  2.163138e-01       True
# 55                   xslgdiff  8.179850e-01       True
# 56                   wobadiff  9.006187e-01       True
# 57         swing_miss_percent  8.801289e-01       True
# 58                  arm_angle  4.615946e-02      False

# %% [markdown]
# Before I go looking for correlations I should look at removing some outliers to ensure that the data is clean.

# %%
#Create Z_score dataframe to identify outliers

#Z-scores
numeric_cols = data.select_dtypes(include=[np.number])
zscores = stats.zscore(numeric_cols)

#Create data frame and add player names back 
z_scores_df = pd.DataFrame(zscores, columns=numeric_cols.columns)
z_scores_df['player_name'] = data['player_name']

z_scores_df
# Out:
#      player_id  pitch_percent        ba       iso     babip       slg  \
# 0     0.709196       2.378320  0.975432  0.831424  1.715571  1.049377
# 1    -0.418308       0.358400 -0.062714  0.768340 -0.009625  0.557955
# 2    -0.000668       0.679751  0.860082  1.273012  0.659854  1.325053
# 3    -0.370380       0.610890 -0.264576  1.919624 -1.606074  1.337038
# 4    -0.998094       1.919247 -0.005040  0.279438 -0.138371  0.210364
# ..         ...            ...       ...       ...       ...       ...
# 407   0.866168      -0.008858 -0.149226 -0.241006 -0.601856 -0.233114
# 408   0.439780       0.909287 -0.927836  1.209928 -1.065341  0.533983
# 409   0.878412      -0.605653 -1.158535 -1.770795 -0.807850 -1.827238
# 410   3.282690      -1.776288 -0.005040 -1.707711 -0.370113 -1.299859
# 411  -0.011233      -2.166500 -1.562259 -2.417406 -0.885097 -2.486463
#
#          woba     xwoba       xba      hits       abs  launch_speed  \
# 0    1.095129  0.024490 -0.241914  2.150170  1.998172     -0.007118
# 1    0.353322  0.632323  0.153739  1.247393  1.551712      1.291677
# 2    1.291490  1.118588  0.549393  1.876601  1.779154      0.118572
# 3    0.855133  0.267623 -0.673537  1.302107  1.737035      0.495641
# 4    0.178779  0.535069  0.729235  1.384178  1.678069     -0.258498
# ..        ...       ...       ...       ...       ...           ...
# 407 -0.235760  0.948395  1.232795 -1.433579 -1.615626      0.034778
# 408  0.069690 -1.555874 -2.507931 -1.515650 -1.624050      0.579434
# 409 -1.741191 -1.264114 -0.637568 -1.543007 -1.632474     -0.635568
# 410 -0.846660 -0.072763  0.621330 -1.378866 -1.565084     -0.384188
# 411 -2.264820 -0.948041 -0.098040 -1.570364 -1.615626     -2.060053
#
#      launch_angle  spin_rate  velocity  effective_speed    whiffs    swings  \
# 0        1.180417   0.914493 -0.576647        -0.195055  3.542330  2.448705
# 1        0.704342  -0.110975  1.726501         1.988243  2.405812  2.273697
# 2        1.505013   1.550990  1.726501         1.883444  2.378426  2.068252
# 3        2.132566   0.666966  0.309179         0.206671  1.077592  2.045425
# 4        0.228268   0.949854 -2.348299        -2.273555  2.529049  1.912266
# ..            ...        ...       ...              ...       ...       ...
# 407     -1.416353   0.348717 -2.171134        -1.871828 -1.428225 -1.641166
# 408      1.266976  -0.040253  0.486344         0.590932 -1.387146 -1.648775
# 409     -0.442564   0.101191 -2.702629        -2.919811 -1.482997 -1.705843
# 410     -0.767161  -0.464585 -0.753812        -0.876244 -1.825322 -1.732474
# 411      0.596144  -1.525414  0.309179         0.101873 -1.606234 -1.747693
#
#      takes  eff_min_vel  release_extension  pitcher_run_exp   run_exp  \
# 0      NaN     1.530100          -1.244803        -0.701152  0.701152
# 1      NaN     1.530100           1.381569         1.194325 -1.194325
# 2      NaN     0.744063           0.665286        -1.577453  1.577453
# 3      NaN    -0.041973          -0.050998        -0.224901  0.224901
# 4      NaN    -0.041973           0.426525         0.918100 -0.918100
# ..     ...          ...                ...              ...       ...
# 407    NaN     1.530100           1.620330        -0.215376  0.215376
# 408    NaN     0.744063           1.381569        -0.882127  0.882127
# 409    NaN    -0.828009          -0.289759        -0.339201  0.339201
# 410    NaN    -0.828009           0.187764        -0.596377  0.596377
# 411    NaN    -0.828009          -0.289759        -0.148701  0.148701
#
#      bat_speed  swing_length        pa       bip   singles   doubles  \
# 0    -0.026464      0.525710  1.992872  1.554317  1.613814  3.284481
# 1     0.910231      0.001273  1.558442  1.244955  0.833069  1.603330
# 2     0.835296      2.099020  1.758948  1.534982  1.440315  1.963577
# 3     0.647957     -0.260945  1.733885  1.738001  0.572820  0.522591
# 4     0.198343      0.787928  1.658695  1.631657  1.180067  1.603330
# ..         ...           ...       ...       ...       ...       ...
# 407   0.348214      0.263491 -1.616234 -1.481294 -1.422418 -1.278642
# 408  -0.326206      0.001273 -1.632943 -1.597305 -1.769416 -0.918395
# 409  -1.038095     -0.523164 -1.624588 -1.548967 -1.379043 -1.518806
# 410  -0.288739      0.263491 -1.574462 -1.384619 -1.162170 -1.398724
# 411  -1.974790     -1.572037 -1.616234 -1.548967 -1.335669 -1.638888
#
#       triples       hrs        so  k_percent  bb_percent  \
# 0    1.408429  1.348818  3.162838   1.101788         NaN
# 1   -0.233852  1.584091  2.349906   0.825261         NaN
# 2   -0.781280  2.407544  2.106027   0.445036         NaN
# 3    0.313575  3.466269  1.130508  -0.367263         NaN
# 4    1.408429  0.878274  1.211801  -0.246282         NaN
# ..        ...       ...       ...        ...         ...
# 407 -0.233852 -1.003905 -1.633461  -1.214127         NaN
# 408 -0.233852 -0.768632 -1.226995   0.548734         NaN
# 409 -0.781280 -1.239177 -1.389581  -0.177150         NaN
# 410 -0.781280 -1.239177 -1.836694  -2.112840         NaN
# 411 -0.781280 -1.356813 -1.389581  -0.194433         NaN
#
#      api_break_z_with_gravity  api_break_z_induced  api_break_x_arm  \
# 0                    1.067482            -1.540780        -1.647158
# 1                   -1.445959             1.069578         0.617313
# 2                   -1.549358             1.134994         0.190404
# 3                   -0.061333            -0.132549        -0.348190
# 4                    2.586217            -2.470640        -3.120327
# ..                        ...                  ...              ...
# 407                  0.984142            -0.283842        -1.434629
# 408                 -1.231197             1.889664         0.305920
# 409                  1.307990            -0.136582        -0.232012
# 410                  0.310699             0.012919        -0.782237
# 411                 -0.103520             1.163072         1.485804
#
#      api_break_x_batter_in  hyper_speed    bbdist  hardhit_percent  \
# 0                 0.726027    -0.417879  1.920724         0.156492
# 1                -0.151021     0.774707  1.836170         1.190249
# 2                 1.492105     0.015789  1.328848         0.360020
# 3                -1.182345     0.449456  1.328848         0.476101
# 4                 0.356183    -0.309462  0.314203        -0.229914
# ..                     ...          ...       ...              ...
# 407              -0.134500     0.883124 -1.630532         0.808003
# 408              -0.664935     0.015789  1.328848         0.585335
# 409               0.117326    -0.526295 -1.715086        -0.448482
# 410               0.325508     0.666290 -1.292317         0.019672
# 411              -1.417593    -2.260965  0.398757        -2.454447
#
#      barrels_per_bbe_percent  barrels_per_pa_percent  release_pos_z  \
# 0                   0.325089                0.199880       0.231355
# 1                   1.285595                1.211707       1.420356
# 2                   1.165809                1.181649       0.033188
# 3                   1.069517                1.262444      -0.759479
# 4                   0.108219                0.190224       1.618523
# ..                       ...                     ...            ...
# 407                -0.341016               -0.183360      -0.363146
# 408                -0.101844               -0.146815       0.429522
# 409                -1.631270               -1.703040       1.222189
# 410                -0.969796               -0.849361       1.024022
# 411                -1.346977               -1.401516      -0.759479
#
#      release_pos_x   plate_x   plate_z       obp  barrels_total  \
# 0         0.282333  1.852782 -1.399631  0.988617       1.185803
# 1        -0.150625  0.780064  1.175736 -0.082871       1.982570
# 2         0.017748 -0.292654  1.175736  0.901739       2.115365
# 3        -0.198731 -0.185382  0.122177 -0.285585       2.181762
# 4         0.065854  1.423695  0.941611  0.032966       0.986611
# ..             ...       ...       ...       ...            ...
# 407       0.691238  1.316423 -0.580196 -0.140789      -0.938909
# 408      -1.088700 -1.365372  0.473363 -0.864767      -0.938909
# 409       1.268516  1.316423  0.239239 -1.212277      -1.270895
# 410       0.378546 -0.721741 -0.229010  0.061925      -1.071703
# 411      -1.425446  0.029161  0.005114 -1.501868      -1.204498
#
#      batter_run_value_per_100      xobp      xslg  pitcher_run_value_per_100  \
# 0                    1.027877 -0.262047  0.163088                  -1.027877
# 1                    0.082594  0.171251  0.760862                  -0.082594
# 2                    1.469778  0.532331  1.307762                  -1.469778
# 3                    0.765388 -0.659236  0.659114                  -0.765388
# 4                    0.136944  0.712872  0.442897                  -0.136944
# ..                        ...       ...       ...                        ...
# 407                 -1.375118  1.182277  0.722707                   1.375118
# 408                  0.562673 -2.500748 -0.917993                  -0.562673
# 409                 -1.221100 -0.370371 -1.655671                   1.221100
# 410                 -0.452366  0.640656 -0.371093                   0.452366
# 411                 -1.998843 -0.081506 -1.223239                   1.998843
#
#       xbadiff  xobpdiff  xslgdiff  wobadiff  swing_miss_percent  arm_angle  \
# 0    1.903661  1.934432  1.700550  1.902785            1.320167  -0.107606
# 1   -0.302749 -0.355355 -0.302021 -0.379618            0.430052  -0.107606
# 2    0.683094  0.766173  0.175866  0.510132            0.591891   1.209235
# 3    0.448369  0.392331  1.359203  1.090404           -0.686638   0.067973
# 4   -0.959977 -0.869388 -0.393046 -0.534357            0.915570   0.770288
# ..        ...       ...       ...       ...                 ...        ...
# 407 -1.851930 -1.757265 -1.735679 -1.927010           -0.282040  -0.283185
# 408  1.762826  1.840971  2.656322  2.599111           -0.006914  -1.775605
# 409 -1.053867 -1.476883 -0.506829 -1.075944           -0.298224   1.297025
# 410 -0.819143 -0.729197 -1.803948 -1.385423           -2.353581   0.243552
# 411 -2.415269 -2.318029 -2.532156 -2.507282           -0.897029  -0.370974
#
#             player_name
# 0       Tovar, Ezequiel
# 1           Olson, Matt
# 2         Adames, Willy
# 3    Santander, Anthony
# 4     Castellanos, Nick
# ..                  ...
# 407        Crews, Dylan
# 408       Clemens, Kody
# 409     Hernaiz, Darell
# 410       Lee, Jung Hoo
# 411         Wade, Tyler
#
# [412 rows x 60 columns]

# %% [markdown]
# Lets look at some outliers! I'm going to use the z_scores data frame I've made to identify some players that are outliers in some important stats.
#
# To start? Bat speed of course!

# %%
#return bat speed outliers that are at least 3 standard devations from the mean. 

#Find players using z_scores
batSpeed_outliers = z_scores_df.loc[np.abs(z_scores_df['bat_speed']) >= 3]

#Display players
data.iloc[batSpeed_outliers.index]
# Out:
#      player_id         player_name  pitch_percent     ba    iso  babip    slg  \
# 59      650333        Arraez, Luis           39.7  0.312  0.089  0.315  0.401
# 165     519317  Stanton, Giancarlo           39.0  0.267  0.285  0.283  0.552
#
#       woba  xwoba    xba  hits  abs  launch_speed  launch_angle  spin_rate  \
# 59   0.308  0.311  0.310   158  506          86.7          15.0       2237
# 165  0.343  0.372  0.288    90  337          95.7          15.9       2267
#
#      velocity  effective_speed  whiffs  swings  takes  eff_min_vel  \
# 59       90.2            90.42      56     959      0          0.2
# 165      88.8            89.13     230     715      0          0.3
#
#      release_extension  pitcher_run_exp  run_exp  bat_speed  swing_length  \
# 59                6.49             13.6    -13.6       63.1           6.0
# 165               6.53             -2.1      2.1       81.2           8.6
#
#       pa  bip  singles  doubles  triples  hrs  so  k_percent  bb_percent  \
# 59   507  493      124       27        3    4  14        2.8           0
# 165  339  252       46       18        0   26  87       25.7           0
#
#      api_break_z_with_gravity  api_break_z_induced  api_break_x_arm  \
# 59                    2.12732              0.72341          0.47132
# 165                   2.32158              0.62979          0.26245
#
#      api_break_x_batter_in  hyper_speed  bbdist  hardhit_percent  \
# 59                -0.26583         90.1     172        23.326572
# 165               -0.08038         95.7     176        58.333333
#
#      barrels_per_bbe_percent  barrels_per_pa_percent  release_pos_z  \
# 59                  1.825558                1.775148           5.69
# 165                21.825397               16.224189           5.80
#
#      release_pos_x  plate_x  plate_z    obp  barrels_total  \
# 59           -0.87    -0.11     2.31  0.312              9
# 165          -0.69     0.06     2.42  0.265             55
#
#      batter_run_value_per_100   xobp   xslg  pitcher_run_value_per_100  \
# 59                  -1.416058  0.310  0.407                   1.416058
# 165                  0.295944  0.288  0.592                  -0.295944
#
#      xbadiff  xobpdiff  xslgdiff  wobadiff  swing_miss_percent  arm_angle
# 59     0.002     0.002    -0.006    -0.003                 5.8       36.6
# 165   -0.021    -0.023    -0.040    -0.029                32.2       39.9

# %% [markdown]
# Now lets take a look back at bat speed distribution and high light our ourliers

# %%
y_col = 'swing_miss_percent' #copmpare bat speed to 


# Find outlier indices where z-score is ≥ 3 or ≤ -3
outlier_indices = z_scores_df.index[(np.abs(z_scores_df['bat_speed']) >= 3)]
outlier_x_values = data.loc[outlier_indices, 'bat_speed']
outlier_y_values = data.loc[outlier_indices, y_col]

# Create scatter plot
plt.scatter(data['bat_speed'], data[y_col], color='blue', label='Data Points', alpha=0.6)
#need to be second to cover origonal point
plt.scatter(outlier_x_values, outlier_y_values, color='pink', label='Outliers', s=80, edgecolor='black')

# Labels and title
plt.title(f'Bat Speed vs {y_col} with Outliers Highlighted')
plt.xlabel("Bat Speed")
plt.ylabel(y_col) 
plt.legend()
plt.show()

# %%
#Outliers in high swing and miss percent

#return bat speed outliers that are at least 3 standard devations from the mean. 

#Find players using z_scores
swingMiss_outliers = z_scores_df.loc[np.abs(z_scores_df['swing_miss_percent']) >= 3]

#Display players
data.iloc[swingMiss_outliers.index]
# Out:
#      player_id   player_name  pitch_percent     ba    iso  babip    slg  \
# 398     668832  McCann, Kyle           39.3  0.282  0.173  0.377  0.455
#
#       woba  xwoba    xba  hits  abs  launch_speed  launch_angle  spin_rate  \
# 398  0.315  0.265  0.214    31  110          91.0          13.4       2271
#
#      velocity  effective_speed  whiffs  swings  takes  eff_min_vel  \
# 398      88.1            88.35     107     250      0          0.3
#
#      release_extension  pitcher_run_exp  run_exp  bat_speed  swing_length  \
# 398               6.42              3.1     -3.1       73.6           7.8
#
#       pa  bip  singles  doubles  triples  hrs  so  k_percent  bb_percent  \
# 398  110   74       22        4        0    5  36       32.7           0
#
#      api_break_z_with_gravity  api_break_z_induced  api_break_x_arm  \
# 398                   2.51572              0.54197           0.2592
#
#      api_break_x_batter_in  hyper_speed  bbdist  hardhit_percent  \
# 398               -0.28304         92.2     146        39.189189
#
#      barrels_per_bbe_percent  barrels_per_pa_percent  release_pos_z  \
# 398                12.162162                8.181818           5.71
#
#      release_pos_x  plate_x  plate_z    obp  barrels_total  \
# 398          -1.67    -0.13     2.43  0.282              9
#
#      batter_run_value_per_100   xobp   xslg  pitcher_run_value_per_100  \
# 398                   -1.2244  0.214  0.412                     1.2244
#
#      xbadiff  xobpdiff  xslgdiff  wobadiff  swing_miss_percent  arm_angle
# 398    0.068     0.068     0.043      0.05                42.8       35.9

# %%
#Outliers in swing_length
 

#Find players using z_scores
swingLength_outliers = z_scores_df.loc[np.abs(z_scores_df['swing_length']) >= 3]

#Display players
data.iloc[swingLength_outliers.index]
# Out:
#      player_id         player_name  pitch_percent     ba    iso  babip    slg  \
# 59      650333        Arraez, Luis           39.7  0.312  0.089  0.315  0.401
# 69      668930       Turang, Brice           37.5  0.253  0.091  0.283  0.344
# 165     519317  Stanton, Giancarlo           39.0  0.267  0.285  0.283  0.552
# 303     595879        Báez, Javier           41.5  0.184  0.126  0.204  0.311
#
#       woba  xwoba    xba  hits  abs  launch_speed  launch_angle  spin_rate  \
# 59   0.308  0.311  0.310   158  506          86.7          15.0       2237
# 69   0.256  0.271  0.272   109  430          86.8           6.4       2244
# 165  0.343  0.372  0.288    90  337          95.7          15.9       2267
# 303  0.209  0.275  0.243    38  206          89.3          11.3       2295
#
#      velocity  effective_speed  whiffs  swings  takes  eff_min_vel  \
# 59       90.2            90.42      56     959      0          0.2
# 69       90.0            90.29     128     926      0          0.3
# 165      88.8            89.13     230     715      0          0.3
# 303      87.8            88.05     123     427      0          0.3
#
#      release_extension  pitcher_run_exp  run_exp  bat_speed  swing_length  \
# 59                6.49             13.6    -13.6       63.1           6.0
# 69                6.46             26.0    -26.0       66.2           6.1
# 165               6.53             -2.1      2.1       81.2           8.6
# 303               6.43             12.8    -12.8       74.8           8.6
#
#       pa  bip  singles  doubles  triples  hrs  so  k_percent  bb_percent  \
# 59   507  493      124       27        3    4  14        2.8           0
# 69   433  373       84       16        4    5  60       13.9           0
# 165  339  252       46       18        0   26  87       25.7           0
# 303  208  167       22       11        0    5  41       19.7           0
#
#      api_break_z_with_gravity  api_break_z_induced  api_break_x_arm  \
# 59                    2.12732              0.72341          0.47132
# 69                    2.19600              0.65915          0.46312
# 165                   2.32158              0.62979          0.26245
# 303                   2.50902              0.49373          0.06539
#
#      api_break_x_batter_in  hyper_speed  bbdist  hardhit_percent  \
# 59                -0.26583         90.1     172        23.326572
# 69                -0.29006         90.3     161        28.150134
# 165               -0.08038         95.7     176        58.333333
# 303               -0.06911         92.3     144        43.113772
#
#      barrels_per_bbe_percent  barrels_per_pa_percent  release_pos_z  \
# 59                  1.825558                1.775148           5.69
# 69                  2.144772                1.847575           5.71
# 165                21.825397               16.224189           5.80
# 303                 9.580838                7.692308           5.63
#
#      release_pos_x  plate_x  plate_z    obp  barrels_total  \
# 59           -0.87    -0.11     2.31  0.312              9
# 69           -1.19    -0.07     2.37  0.252              8
# 165          -0.69     0.06     2.42  0.265             55
# 303          -1.19     0.18     2.25  0.183             16
#
#      batter_run_value_per_100   xobp   xslg  pitcher_run_value_per_100  \
# 59                  -1.416058  0.310  0.407                   1.416058
# 69                  -2.803888  0.271  0.351                   2.803888
# 165                  0.295944  0.288  0.592                  -0.295944
# 303                 -3.007494  0.243  0.396                   3.007494
#
#      xbadiff  xobpdiff  xslgdiff  wobadiff  swing_miss_percent  arm_angle
# 59     0.002     0.002    -0.006    -0.003                 5.8       36.6
# 69    -0.019    -0.019    -0.007    -0.015                13.8       38.0
# 165   -0.021    -0.023    -0.040    -0.029                32.2       39.9
# 303   -0.059    -0.060    -0.085    -0.066                28.8       37.6

# %%
y_col = 'xwoba' #copmpare bat speed to 


# Find outlier indices where z-score is ≥ 3 or ≤ -3
outlier_indices = z_scores_df.index[(np.abs(z_scores_df['bat_speed']) >= 3)]


# Create scatter plot
plt.scatter(data['bat_speed'], data[y_col], color='blue', label='Data Points', alpha=0.6)


# Labels and title
plt.title(f'Bat Speed vs {y_col}')
plt.xlabel("Bat Speed")
plt.ylabel(y_col) 
plt.show()

# %%
y_col = 'slg' #copmpare bat speed to 


# Find outlier indices where z-score is ≥ 3 or ≤ -3
outlier_indices = z_scores_df.index[(np.abs(z_scores_df['bat_speed']) >= 3)]


# Create scatter plot
plt.scatter(data['bat_speed'], data[y_col], color='blue', label='Data Points', alpha=0.6)


# Labels and title
plt.title(f'Bat Speed vs {y_col}')
plt.xlabel("Bat Speed")
plt.ylabel(y_col) 
plt.show()
